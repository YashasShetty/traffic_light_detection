# %%
from ultralytics import YOLO

# Load your YOLOv26m model
model = YOLO("yolo26m.pt")

# Export to OpenVINO format
# 'format="openvino"' creates a folder containing .xml and .bin files
model.export(format="openvino", dynamic=True)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.10.12 torch-2.10.0+cu128 CPU (12th Gen Intel Core i7-12700K)
# YOLO26m summary (fused): 132 layers, 20,411,132 parameters, 0 gradients, 68.2 GFLOPs
#
# PyTorch: starting from 'yolo26m.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (42.2 MB)
# requirements: Ultralytics requirement ['openvino>=2024.0.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/53.4 MB ? eta -:--:--
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/53.4 MB 11.8 MB/s eta 0:00:05
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/53.4 MB 6.4 MB/s eta 0:00:08
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/53.4 MB 8.3 MB/s eta 0:00:06
#    ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/53.4 MB 9.2 MB/s eta 0:00:06
#    ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/53.4 MB 9.7 MB/s eta 0:00:05
#    ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/53.4 MB 10.1 MB/s eta 0:00:05
# ...
